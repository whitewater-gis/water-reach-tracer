# %%
from arcgis.gis import GIS, Item

# %%
web_gis = GIS(username='joel_mccune')
web_gis
# Out:
# GIS @ <a href="https://jdm1cc.maps.arcgis.com">https://jdm1cc.maps.arcgis.com</a>

# %%
lyr = Item(web_gis, 'cddda6482e4540158aa705675b33371c').layers[0]
lyr
# Out:
# <FeatureLayer url:"http://services5.arcgis.com/12oODIpfxlRR11MF/arcgis/rest/services/hydroline/FeatureServer/0">

# %%
sdf = lyr.query().df
sdf.head()
# Out:
#    LengthMiles  OBJECTID   created_date created_user  difficulty  \
# 0     3.315622         1  1459206045000     JOEL5174     II-III+
# 1     0.251997         2  1459206045000     JOEL5174   III-V(V+)
# 2     4.278405         3  1459206045000     JOEL5174   III-V(V+)
# 3     6.391808         4  1459206045000     JOEL5174  II-III(IV)
# 4     4.559789         5  1459206045000     JOEL5174     III-IV+
#
#   difficulty_max difficulty_min difficulty_outlier  last_edited_date  \
# 0           III+             II               None     1463469434000
# 1              V            III                 V+     1463469434000
# 2              V            III                 V+     1463469434000
# 3            III             II                 IV     1463469434000
# 4            IV+            III               None     1463469434000
#
#   last_edited_user  manual_digitize      name_common      name_river  \
# 0         JOEL5174                0             None   Montana Creek
# ...

# %%
sdf.iloc[0].SHAPE
# Out:
# {'paths': [[[-134.647080638, 58.4407740670001],
#    [-134.647012723, 58.440562884],
#    [-134.646851309, 58.4400609570001],
#    [-134.646819243, 58.4399612440001],
#    [-134.646795272, 58.439943634],
#    [-134.646536804, 58.4398460030001],
#    [-134.646504207, 58.439833691],
#    [-134.646186109, 58.439713533],
#    [-134.646086423, 58.439680777],
#    [-134.645697602, 58.4395529980001],
#    [-134.645651393, 58.4395145930001],
#    [-134.645614058, 58.4394835580001],
#    [-134.645588239, 58.4394620990001],
#    [-134.645386007, 58.439293998],
#    [-134.645385466, 58.439293547],
#    [-134.645385158, 58.4392932920001],
#    [-134.64536316, 58.4392690510001],
#    [-134.645125502, 58.439007184],
#    [-134.645074368, 58.4389572470001],
#    [-134.645017726, 58.4389019330001],
#    [-134.644845324, 58.438733561],
#    [-134.644815311, 58.4387068660001],
#    [-134.644782387, 58.43867758],
#    [-134.644520338, 58.4384445090001],
#    [-134.644523433, 58.438311899],
# ...
