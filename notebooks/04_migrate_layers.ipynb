# %%
from arcgis.gis import GIS
import os

from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())

import sys
sys.path.append('../src')

import reach_tools

# %%
url_reach_line = os.getenv('URL_REACH_LINE')
url_reach_centroid = os.getenv('URL_REACH_CENTROID')
url_reach_points = os.getenv('URL_REACH_POINT')

# %%
gis = GIS(username=os.getenv('ARCGIS_USERNAME'), password=os.getenv('ARCGIS_PASSWORD'))
gis
# Out:
# GIS @ https://knu2xs.maps.arcgis.com version:6.4

# %%
lyr_reach_line = reach_tools.ReachFeatureLayer(url_reach_line, gis)
lyr_reach_centroid = reach_tools.ReachFeatureLayer(url_reach_centroid, gis)
lyr_reach_points = reach_tools.ReachPointFeatureLayer(url_reach_points, gis)

# %%
df = lyr_reach_centroid.query().sdf
df
# Out:
#                                GlobalID  OBJECTID  \
# 0  5c7dba5b-6073-4bda-8be4-4d3668f28068         1
# 1  6df01625-c6f5-4ef4-bc86-3524ef42bcac         2
# 2  8791ae9a-a8eb-4e6c-b55e-40b102d82887         3
# 3  b869449d-8017-4538-a635-a054989ea72c         4
# 4  3e058456-fd86-47c0-b339-12a8a69a51f8         5
# 5  05a99227-2b01-4d41-8a9f-5d579eb17a34         6
#
#                                                SHAPE  \
# 0  {"x": -13540819.70610396, "y": 5741463.4395831...
# 1  {"x": -13524978.504410567, "y": 5772153.034339...
# 2  {"x": -13525886.313967427, "y": 5761191.447963...
# 3  {"x": -13526735.08590027, "y": 5750805.8378675...
# 4  {"x": -13619334.086352017, "y": 5772426.552403...
# 5  {"x": -13612367.059061443, "y": 5597733.672227...
#
#                                             abstract collection_method  \
# 0  Washington's best known class V run flowing ye...              None
# 1  Dramatic gorge with numerous ledge drops that ...              None
# 2  Well known for Big Brother this river is a pro...              None
# 3  A classic intermediate run that flows througho...              None
# 4  A classic creek run with a series of outstandi...              None
# 5  Known to locals as Lower Opal Creek, this run ...              None
#
#                    created_date created_user  \
# 0 2019-03-11 16:12:21.256000041       knu2xs
# 1 2019-03-11 16:12:21.256000041       knu2xs
# 2 2019-03-11 16:12:21.256000041       knu2xs
# 3 2019-03-11 16:12:21.256000041       knu2xs
# 4 2019-03-11 16:12:21.256000041       knu2xs
# 5 2019-03-11 16:12:21.256000041       knu2xs
#
#                                          description difficulty  \
# 0  The Little White Salmon is a highlight of Paci...          V
# 1  Dramatic gorge with numerous ledge drops that ...       IV-V
# 2  This run is characterized by big drops and an ...          V
# 3  Emerging from the slopes of Mt. Adams, the Whi...    III+(V)
# 4  Events: Annual Canyon Creek Extreme Race Logis...        IV+
# 5  **Flows:** This section has been run below 400...  III-IV(V)
#
#   difficulty_maximum  ... notes reach_id  \
# 0                  V  ...           2156
# 1                  V  ...           2269
# 2                  V  ...           2270
# 3               III+  ...           3064
# 4                IV+  ...           3066
# 5                 IV  ...           5199
#
#                                          reach_name reach_name_alternate  \
# 0                         Willard to Columbia River
# 1  2 - Trout Lake to Green Truss Bridge (Farmlands)
# 2              3 - Green Truss Bridge to BZ Corners
# 3                       4 - BZ Corner to Buck Creek
# 4                 2 - Fly Creek to Merwin Reservoir
# 5                     2\. Gold Creek to Three Pools
#
#                              river_name river_name_alternate update_arcgis  \
# 0                   Little White Salmon                                NaT
# 1                          White Salmon                                NaT
# 2                          White Salmon                                NaT
# 3                          White Salmon                                NaT
# 4      Canyon Creek (Lewis River trib.)                                NaT
# 5  Santiam, Little North (Classic Opal)                                NaT
#
#             update_aw validated validated_by
# 0 2019-01-25 06:37:13      None
# 1 2013-12-04 13:16:45      None
# 2 2013-12-04 13:25:47      None
# 3 2017-01-05 10:47:33      None
# 4 2014-11-08 14:50:28      None
# 5 2018-03-30 05:22:10      None
#
# [6 rows x 25 columns]
