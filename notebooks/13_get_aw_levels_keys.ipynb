# %%
import requests
import pandas as pd
import math
from datetime import datetime, timedelta
import time

# %%
reach_id = '3066'

# %%
aw_attempts = 0

def get_gauge_keys(reach_id):

    aw_resp = requests.get(f'https://www.americanwhitewater.org/content/River/detail/id/{reach_id}/.json')

    if aw_resp.status_code == 200:

        resp_json = aw_resp.json()
        
        if len(resp_json['CContainerViewJSON_view']['CRiverMainGadgetJSON_main']['gauges']):
        
            gauge_info = resp_json['CContainerViewJSON_view']['CRiverMainGadgetJSON_main']['gauges'][0]
            return list(gauge_info.keys())
        
        else:
            return None

    else:
        return None

# %%
key_lst = []
for reach_id in range(1000, 6000):
    new_keys = get_gauge_keys(reach_id)
    if new_keys:
        key_lst = list(set(new_keys + key_lst))
print(key_lst)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-4729f1a2045d> in <module>()
#       1 key_lst = []
#       2 for reach_id in range(1000, 6000):
# ----> 3     new_keys = get_gauge_keys(reach_id)
#       4     if new_keys:
#       5         key_lst = list(set(new_keys + key_lst))
#
# <ipython-input-15-671e32b6b6fb> in get_gauge_keys(reach_id)
#       3 def get_gauge_keys(reach_id):
#       4
# ----> 5     aw_resp = requests.get(f'https://www.americanwhitewater.org/content/River/detail/id/{reach_id}/.json')
#       6
#       7     if aw_resp.status_code == 200:
#
# /opt/conda/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ...

# %%
key_lst
# Out:
# ['range_min',
#  'sourceid',
#  'did',
#  'max',
#  'gauge_estimated',
#  'source',
#  'targetid',
#  'metric_unit',
#  'min',
#  'gauge_min',
#  'glon',
#  'rc',
#  'rmin',
#  'range_max',
#  'class',
#  'last_gauge_updated',
#  'id',
#  'epoch',
#  'gauge_max',
#  'adjusted_reach_class',
#  'metricid',
#  'gauge_id',
#  'gauge_comment',
#  'time_adjustment',
#  'url',
#  'source_id',
#  'rmax',
#  'gauge_important',
#  'excluded',
#  'gauge_name',
#  'obs_id',
#  'gauge_data',
#  'range_comment',
#  'gauge_perfect',
#  'last_gauge_reading',
#  'gauge_reading',
#  'reading',
#  'glat',
#  'gauge_metric',
#  'dhid',
#  'updated']
